# %% [markdown]
# ## MCE to Determine Highest-Risk Intersection most in Need of Leading Pedestrian Interval Signals
# ![NYC Streetlight Intersection](images/street_NYC.png)
# <details>
#   <summary>Introduction!</summary>
#
# ###### With the fast-paced hustle-and-bustle movement of pedestrians, vehicles and bicycles that all need to get from point A to point B in a ‘New York Minute’, city planners and lawmakers alike know the dangers traffic accidents present in the city that never sleeps. In 2014, New York City passed a new policy known as Vision Zero, which seeks to eliminate as many traffic accidents and pedestrian casualties as possible. In 2014 alone, 3,000 New Yorkers were seriously injured, and more than 200 were killed in traffic crashes. The leading cause of injury-related deaths for children under 14 and the second leading cause for senior citizens is being struck by moving vehicles. New York City has taken many proactive measures in limiting traffic collisions and pedestrian deaths by implementing Leading Pedestrian Interval Signals(LPIS) throughout the five boroughs. These signals allow pedestrians a head start to walk across the crosswalk before the green is given to vehicles, giving drivers more visibility of possible pedestrians in the process. There are currently over 4,000 of LPISs installed and working, but the goal of this research is to use a Multi-Criteria Evaluation(MCE) of New York City’s streets and intersections to determine the intersections most in need of LPIS installation.
#
#
#
# NOTE: This notebook and subsequent notebooks will serve as a guide on how to clean and refine large datasets, conduct spatial analysis in PostGIS as well as python, standardize variables of interest, and present final data findings in interactive and aesthetic maps.
#
# contact:Steven.Nacinovich27@myhunter.cuny.edu

# %% [markdown]
# ## Part 1: Cleaning our Collisions and pedestrian data-sets
#
#  Data retrieved from:
#  https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95
#  &
#  https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Person/f55k-p6yu
#
# Collision crash table contains information from all police reported motor vehicle collisions since 2014, when Vision Zero was first created. The police report is required to be filled out when someone is injured, killed, or there is more than $1,000 dollars in reported damages. There are 1.68 million records in total.
#
# The person crash table contains information for each person involved in motor vehicle collisions since 2016. There are 3.92 million records in total.

# %%
# %matplotlib inline

# Import libraries used below
import pandas as pd
import geopandas as gpd
import numpy as np
import json
from sqlalchemy import create_engine
from shapely import wkt

# %% [markdown]
# Reading in data using pandas library

# %%
collision = pd.read_csv("F:\GeoCompII\project\Data\City_OpenData\Motor_Vehicle_Collisions_-_Crashes.csv")
pedestrian = pd.read_csv("F:\GeoCompII\project\Data\City_OpenData\Motor_Vehicle_Collisions_-_Person.csv")

# %%
# view the collision data
collision.head()
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  03/03/2020       0:00   BROOKLYN    11208  40.68992  -73.87261
# 1  03/13/2019      10:15  MANHATTAN    10004       NaN        NaN
# 2  04/02/2015       1:15        NaN      NaN       NaN        NaN
# 3  04/02/2015      22:30        NaN      NaN       NaN        NaN
# 4  03/03/2020      11:20  MANHATTAN    10036       NaN        NaN
#
#                      LOCATION                    ON STREET NAME  \
# 0  POINT (-73.87261 40.68992)  HEMLOCK STREET
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN  BRUCKNER BOULEVARD
# 4                         NaN  W 46th STREET
#
#                   CROSS STREET NAME                           OFF STREET NAME  \
# 0                    JAMAICA AVENUE                                       NaN
# 1                               NaN  10        South street
# 2                               NaN                                       NaN
# 3  ZEREGA AVENUE                                                          NaN
# 4                       12TH AVENUE                                       NaN
#
#    ...   CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0  ...                             NaN                            NaN
# 1  ...                             NaN                            NaN
# 2  ...  Driver Inattention/Distraction                            NaN
# 3  ...                     Unspecified                            NaN
# 4  ...                     Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       4297861
# 1                            NaN                            NaN       4096508
# 2                            NaN                            NaN       3196332
# 3                            NaN                            NaN       3197387
# 4                            NaN                            NaN       4297078
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                  NaN                  NaN
# 1  Station Wagon/Sport Utility Vehicle                  NaN
# 2                    PASSENGER VEHICLE    PASSENGER VEHICLE
# 3                              UNKNOWN    PASSENGER VEHICLE
# 4                            Box Truck            Box Truck
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
# view pedestrian data
pedestrian.head()
# Out:
#    UNIQUE_ID  COLLISION_ID  CRASH_DATE CRASH_TIME  \
# 0   10252788       4230640  10/25/2019      17:42
# 1   10253512       4230733  10/10/2019      19:45
# 2   10250662       4230235  10/26/2019      10:40
# 3   10252894       4231115  10/26/2019      18:45
# 4    6650180       3565527  11/21/2016      13:05
#
#                               PERSON_ID PERSON_TYPE PERSON_INJURY  VEHICLE_ID  \
# 0  0278267c-0b21-470f-8a54-da71b7361448    Occupant   Unspecified  19142923.0
# 1  81161123-516c-438d-8f29-a107d2783d85    Occupant   Unspecified  19143291.0
# 2  b5da9aa6-3230-4203-bbde-3b6f9248ac31    Occupant       Injured  19141868.0
# 3  4ed210b6-678c-4fe3-ae8c-3ecd30eae7aa  Pedestrian       Injured         NaN
# 4                               2782525    Occupant   Unspecified         NaN
#
#    PERSON_AGE     EJECTION  ...        BODILY_INJURY  \
# 0         0.0  Not Ejected  ...       Does Not Apply
# 1         NaN          NaN  ...                  NaN
# 2        11.0  Not Ejected  ...          Entire Body
# 3        30.0          NaN  ...  Knee-Lower Leg Foot
# 4         NaN          NaN  ...                  NaN
#
#                                  POSITION_IN_VEHICLE SAFETY_EQUIPMENT  \
# 0  Any person in the rear of a station wagon, pic...          Unknown
# 1                                                NaN              NaN
# 2  Middle rear seat, or passenger lying across a ...          Unknown
# 3                                             Driver             None
# 4                                                NaN              NaN
#
#                                         PED_LOCATION               PED_ACTION  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3  Pedestrian/Bicyclist/Other Pedestrian at Inter...  Crossing Against Signal
# 4                                                NaN                      NaN
#
#                             COMPLAINT         PED_ROLE  \
# 0                      Does Not Apply        Passenger
# 1                                 NaN       Registrant
# 2                            Whiplash        Passenger
# 3  Fracture - Distorted - Dislocation       Pedestrian
# 4                                 NaN  Notified Person
#
#                                CONTRIBUTING_FACTOR_1 CONTRIBUTING_FACTOR_2  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  Pedestrian/Bicyclist/Other Pedestrian Error/Co...               Texting
# 4                                                NaN                   NaN
#
#   PERSON_SEX
# 0          F
# 1        NaN
# 2          F
# 3          M
# 4        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# When Viewing the fields and data types in the objects Collision and Pedestrian, they each share one common field(COLLISION_ID). These files can be joined or merged to create one file that has all pedestrian injuries and vehicle collisions.
# In this example, merge was used

# %%
df = collision.merge(pedestrian, how = 'left', left_on = 'COLLISION_ID', right_on = 'COLLISION_ID')
df.head()
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  03/03/2020       0:00   BROOKLYN    11208  40.68992  -73.87261
# 1  03/13/2019      10:15  MANHATTAN    10004       NaN        NaN
# 2  03/13/2019      10:15  MANHATTAN    10004       NaN        NaN
# 3  03/13/2019      10:15  MANHATTAN    10004       NaN        NaN
# 4  04/02/2015       1:15        NaN      NaN       NaN        NaN
#
#                      LOCATION                    ON STREET NAME  \
# 0  POINT (-73.87261 40.68992)  HEMLOCK STREET
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
#
#   CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0    JAMAICA AVENUE                                       NaN  ...
# 1               NaN  10        South street                    ...
# 2               NaN  10        South street                    ...
# 3               NaN  10        South street                    ...
# 4               NaN                                       NaN  ...
#
#          BODILY_INJURY                                POSITION_IN_VEHICLE  \
# 0  Knee-Lower Leg Foot                                                NaN
# 1       Does Not Apply                                             Driver
# 2       Does Not Apply  Middle front seat, or passenger lying across a...
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
#
#      SAFETY_EQUIPMENT                                       PED_LOCATION  \
# 0                 NaN  Pedestrian/Bicyclist/Other Pedestrian at Inter...
# 1  Lap Belt & Harness                                                NaN
# 2  Lap Belt & Harness                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#              PED_ACTION                    COMPLAINT    PED_ROLE  \
# 0  Crossing With Signal  Complaint of Pain or Nausea  Pedestrian
# 1                   NaN               Does Not Apply      Driver
# 2                   NaN               Does Not Apply   Passenger
# 3                   NaN                          NaN  Registrant
# 4                   NaN                          NaN         NaN
#
#    CONTRIBUTING_FACTOR_1 CONTRIBUTING_FACTOR_2 PERSON_SEX
# 0            Unspecified           Unspecified          F
# 1                    NaN                   NaN          F
# 2                    NaN                   NaN          F
# 3                    NaN                   NaN          U
# 4                    NaN                   NaN        NaN
#
# [5 rows x 49 columns]

# %%
print("The number of records is currently: ",len(df))
# Out:
# The number of records is currently:  4492438

# %% [markdown]
# With nearly 4.5 million records, this data at first glance seems large and very expansive, however a good chunk of records do not have spatial data (X,Y) POINT component. These records cannot be used in the analysis since they will not factor into spatial research.

# %%
# Removing Values where there is no location data
df1 = df.dropna(subset = ['LOCATION']) # we are subsetting so only records where no location are removed
print("The number of records is currently: ",len(df1))
# Out:
# The number of records is currently:  4012713

# %%
# removing seriously erroneous coordinates
df1 = df1[(df1['LATITUDE'] > 38) & (df1['LONGITUDE'] <-48) &
          (df1['LONGITUDE'] > -75)]
        
print("The number of records is currently: ",len(df1))
# Out:
# The number of records is currently:  4007788

# %% [markdown]
# Now there are roughly 4.007 million records with a spatial component. The SRID for this data is EPSG:4326.

# %%
pd.options.display.max_columns = None # this is so I can view all 49 columns of data.
df1.head()
# df['CRASH_DATE']= pd.to_datetime(df['CRASH_DATE'])
# Out:
#     CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0   03/03/2020       0:00  BROOKLYN    11208  40.68992  -73.87261
# 12  03/03/2020      13:08  BROOKLYN    11219  40.63693  -73.98657
# 13  03/03/2020      13:08  BROOKLYN    11219  40.63693  -73.98657
# 14  03/03/2020      13:08  BROOKLYN    11219  40.63693  -73.98657
# 15  03/03/2020      13:08  BROOKLYN    11219  40.63693  -73.98657
#
#                       LOCATION                    ON STREET NAME  \
# 0   POINT (-73.87261 40.68992)  HEMLOCK STREET
# 12  POINT (-73.98657 40.63693)                               NaN
# 13  POINT (-73.98657 40.63693)                               NaN
# 14  POINT (-73.98657 40.63693)                               NaN
# 15  POINT (-73.98657 40.63693)                               NaN
#
#    CROSS STREET NAME                           OFF STREET NAME  \
# 0     JAMAICA AVENUE                                       NaN
# 12               NaN  4312      14 AVENUE
# 13               NaN  4312      14 AVENUE
# 14               NaN  4312      14 AVENUE
# 15               NaN  4312      14 AVENUE
#
#     NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                         1.0                       0.0
# 12                        0.0                       0.0
# 13                        0.0                       0.0
# 14                        0.0                       0.0
# 15                        0.0                       0.0
#
#     NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 0                               1                             0
# 12                              0                             0
# 13                              0                             0
# 14                              0                             0
# 15                              0                             0
#
#     NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 0                           0                         0
# 12                          0                         0
# 13                          0                         0
# 14                          0                         0
# 15                          0                         0
#
#     NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 0                            0                          0
# 12                           0                          0
# 13                           0                          0
# 14                           0                          0
# 15                           0                          0
#
#    CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2  \
# 0                            NaN                           NaN
# 12                   Unspecified                   Unspecified
# 13                   Unspecified                   Unspecified
# 14                   Unspecified                   Unspecified
# 15                   Unspecified                   Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                           NaN
# 12                           NaN                           NaN
# 13                           NaN                           NaN
# 14                           NaN                           NaN
# 15                           NaN                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID VEHICLE TYPE CODE 1  \
# 0                            NaN       4297861                 NaN
# 12                           NaN       4297227               Sedan
# 13                           NaN       4297227               Sedan
# 14                           NaN       4297227               Sedan
# 15                           NaN       4297227               Sedan
#
#    VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                  NaN                 NaN                 NaN
# 12               Sedan                 NaN                 NaN
# 13               Sedan                 NaN                 NaN
# 14               Sedan                 NaN                 NaN
# 15               Sedan                 NaN                 NaN
#
#    VEHICLE TYPE CODE 5   UNIQUE_ID  CRASH_DATE CRASH_TIME  \
# 0                  NaN  10583927.0  03/03/2020       0:00
# 12                 NaN  10580837.0  03/03/2020      13:08
# 13                 NaN  10580840.0  03/03/2020      13:08
# 14                 NaN  10580839.0  03/03/2020      13:08
# 15                 NaN  10580838.0  03/03/2020      13:08
#
#                                PERSON_ID PERSON_TYPE PERSON_INJURY  \
# 0   b266d854-0b05-44b5-ad74-940ceaa29ba4  Pedestrian       Injured
# 12  d7faf68e-af75-4b3c-8b74-e45100ab3fc7    Occupant   Unspecified
# 13  cb65e835-8001-4cdf-8704-6fca57ece391    Occupant   Unspecified
# 14  27d6ea6c-4578-4f03-8eea-cd74c70364b2    Occupant   Unspecified
# 15  1c261516-0f1c-428d-bbaf-b665d7404722    Occupant   Unspecified
#
#     VEHICLE_ID  PERSON_AGE     EJECTION EMOTIONAL_STATUS        BODILY_INJURY  \
# 0          NaN        21.0          NaN        Conscious  Knee-Lower Leg Foot
# 12  19310666.0        56.0  Not Ejected   Does Not Apply       Does Not Apply
# 13  19310666.0        56.0          NaN              NaN                  NaN
# 14  19310667.0        33.0  Not Ejected   Does Not Apply       Does Not Apply
# 15  19310667.0        33.0          NaN              NaN                  NaN
#
#    POSITION_IN_VEHICLE    SAFETY_EQUIPMENT  \
# 0                  NaN                 NaN
# 12              Driver  Lap Belt & Harness
# 13                 NaN                 NaN
# 14              Driver  Lap Belt & Harness
# 15                 NaN                 NaN
#
#                                          PED_LOCATION            PED_ACTION  \
# 0   Pedestrian/Bicyclist/Other Pedestrian at Inter...  Crossing With Signal
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
#
#                       COMPLAINT    PED_ROLE CONTRIBUTING_FACTOR_1  \
# 0   Complaint of Pain or Nausea  Pedestrian           Unspecified
# 12               Does Not Apply      Driver                   NaN
# 13                          NaN  Registrant                   NaN
# 14               Does Not Apply      Driver                   NaN
# 15                          NaN  Registrant                   NaN
#
#    CONTRIBUTING_FACTOR_2 PERSON_SEX
# 0            Unspecified          F
# 12                   NaN          M
# 13                   NaN          M
# 14                   NaN          M
# 15                   NaN          M

# %%
# let's view the data by the highest number of people killed in one incident
sort_person_kill = df1.sort_values(by = 'NUMBER OF PERSONS KILLED', ascending = False)
sort_person_kill.head(10)
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 2920724  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920726  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920735  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920736  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920737  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920725  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920723  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920722  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920721  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
# 2920720  10/31/2017      15:08  MANHATTAN    10014  40.729046  -74.01073
#
#                             LOCATION                    ON STREET NAME  \
# 2920724  POINT (-74.01073 40.729046)  WEST STREET
# 2920726  POINT (-74.01073 40.729046)  WEST STREET
# 2920735  POINT (-74.01073 40.729046)  WEST STREET
# 2920736  POINT (-74.01073 40.729046)  WEST STREET
# 2920737  POINT (-74.01073 40.729046)  WEST STREET
# 2920725  POINT (-74.01073 40.729046)  WEST STREET
# 2920723  POINT (-74.01073 40.729046)  WEST STREET
# 2920722  POINT (-74.01073 40.729046)  WEST STREET
# 2920721  POINT (-74.01073 40.729046)  WEST STREET
# 2920720  POINT (-74.01073 40.729046)  WEST STREET
#
#            CROSS STREET NAME OFF STREET NAME  NUMBER OF PERSONS INJURED  \
# 2920724  WEST HOUSTON STREET             NaN                       12.0
# 2920726  WEST HOUSTON STREET             NaN                       12.0
# 2920735  WEST HOUSTON STREET             NaN                       12.0
# 2920736  WEST HOUSTON STREET             NaN                       12.0
# 2920737  WEST HOUSTON STREET             NaN                       12.0
# 2920725  WEST HOUSTON STREET             NaN                       12.0
# 2920723  WEST HOUSTON STREET             NaN                       12.0
# 2920722  WEST HOUSTON STREET             NaN                       12.0
# 2920721  WEST HOUSTON STREET             NaN                       12.0
# 2920720  WEST HOUSTON STREET             NaN                       12.0
#
#          NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 2920724                       8.0                              7
# 2920726                       8.0                              7
# 2920735                       8.0                              7
# 2920736                       8.0                              7
# 2920737                       8.0                              7
# 2920725                       8.0                              7
# 2920723                       8.0                              7
# 2920722                       8.0                              7
# 2920721                       8.0                              7
# 2920720                       8.0                              7
#
#          NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# 2920724                             6                          1
# 2920726                             6                          1
# 2920735                             6                          1
# 2920736                             6                          1
# 2920737                             6                          1
# 2920725                             6                          1
# 2920723                             6                          1
# 2920722                             6                          1
# 2920721                             6                          1
# 2920720                             6                          1
#
#          NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# 2920724                         2                           4
# 2920726                         2                           4
# 2920735                         2                           4
# 2920736                         2                           4
# 2920737                         2                           4
# 2920725                         2                           4
# 2920723                         2                           4
# 2920722                         2                           4
# 2920721                         2                           4
# 2920720                         2                           4
#
#          NUMBER OF MOTORIST KILLED CONTRIBUTING FACTOR VEHICLE 1  \
# 2920724                          0               Other Vehicular
# 2920726                          0               Other Vehicular
# 2920735                          0               Other Vehicular
# 2920736                          0               Other Vehicular
# 2920737                          0               Other Vehicular
# 2920725                          0               Other Vehicular
# 2920723                          0               Other Vehicular
# 2920722                          0               Other Vehicular
# 2920721                          0               Other Vehicular
# 2920720                          0               Other Vehicular
#
#         CONTRIBUTING FACTOR VEHICLE 2 CONTRIBUTING FACTOR VEHICLE 3  \
# 2920724                   Unspecified                   Unspecified
# 2920726                   Unspecified                   Unspecified
# 2920735                   Unspecified                   Unspecified
# 2920736                   Unspecified                   Unspecified
# 2920737                   Unspecified                   Unspecified
# 2920725                   Unspecified                   Unspecified
# 2920723                   Unspecified                   Unspecified
# 2920722                   Unspecified                   Unspecified
# 2920721                   Unspecified                   Unspecified
# 2920720                   Unspecified                   Unspecified
#
#         CONTRIBUTING FACTOR VEHICLE 4 CONTRIBUTING FACTOR VEHICLE 5  \
# 2920724                   Unspecified                   Unspecified
# 2920726                   Unspecified                   Unspecified
# 2920735                   Unspecified                   Unspecified
# 2920736                   Unspecified                   Unspecified
# 2920737                   Unspecified                   Unspecified
# 2920725                   Unspecified                   Unspecified
# 2920723                   Unspecified                   Unspecified
# 2920722                   Unspecified                   Unspecified
# 2920721                   Unspecified                   Unspecified
# 2920720                   Unspecified                   Unspecified
#
#          COLLISION_ID VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2  \
# 2920724       3782508                  FB                  BU
# 2920726       3782508                  FB                  BU
# 2920735       3782508                  FB                  BU
# 2920736       3782508                  FB                  BU
# 2920737       3782508                  FB                  BU
# 2920725       3782508                  FB                  BU
# 2920723       3782508                  FB                  BU
# 2920722       3782508                  FB                  BU
# 2920721       3782508                  FB                  BU
# 2920720       3782508                  FB                  BU
#
#         VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5  \
# 2920724             BICYCLE             BICYCLE             BICYCLE
# 2920726             BICYCLE             BICYCLE             BICYCLE
# 2920735             BICYCLE             BICYCLE             BICYCLE
# 2920736             BICYCLE             BICYCLE             BICYCLE
# 2920737             BICYCLE             BICYCLE             BICYCLE
# 2920725             BICYCLE             BICYCLE             BICYCLE
# 2920723             BICYCLE             BICYCLE             BICYCLE
# 2920722             BICYCLE             BICYCLE             BICYCLE
# 2920721             BICYCLE             BICYCLE             BICYCLE
# 2920720             BICYCLE             BICYCLE             BICYCLE
#
#           UNIQUE_ID  CRASH_DATE CRASH_TIME  \
# 2920724  10542707.0  10/31/2017      15:08
# 2920726  10542708.0  10/31/2017      15:08
# 2920735  10542704.0  10/31/2017      15:08
# 2920736  10542685.0  10/31/2017      15:08
# 2920737  10542709.0  10/31/2017      15:08
# 2920725  10542703.0  10/31/2017      15:08
# 2920723  10542697.0  10/31/2017      15:08
# 2920722  10542691.0  10/31/2017      15:08
# 2920721  10542690.0  10/31/2017      15:08
# 2920720  10542694.0  10/31/2017      15:08
#
#                                     PERSON_ID PERSON_TYPE PERSON_INJURY  \
# 2920724  1d6d60e4-dec8-48e6-b0d4-f7b8eba56395    Occupant       Injured
# 2920726  92424cb6-a7d8-4fda-9a49-0a026d8eba48    Occupant   Unspecified
# 2920735  064f7811-b64b-4704-8557-f222a0dee210    Occupant       Injured
# 2920736  b47c512d-90c5-43bc-a7b0-0c8909b14a26   Bicyclist        Killed
# 2920737  f531a46a-56fb-4cbf-845f-070b23c165dc    Occupant   Unspecified
# 2920725  31b0b62d-0b32-496b-bce4-aa36b57ea111    Occupant       Injured
# 2920723  0cd44019-5f04-46a4-8525-f80208d3b373  Pedestrian       Injured
# 2920722  e6225c3e-0bf8-45e4-82af-995faad219ad  Pedestrian        Killed
# 2920721  87b351b3-5b85-41ad-9e64-897470b57a8c  Pedestrian        Killed
# 2920720  7946c8eb-f0ff-4732-928d-ba7c2d7496c9  Pedestrian        Killed
#
#          VEHICLE_ID  PERSON_AGE     EJECTION EMOTIONAL_STATUS   BODILY_INJURY  \
# 2920724  19290191.0        59.0  Not Ejected        Conscious         Unknown
# 2920726  19290190.0         0.0          NaN              NaN             NaN
# 2920735  19290191.0        16.0  Not Ejected        Conscious         Unknown
# 2920736  19290194.0        32.0      Ejected   Apparent Death         Unknown
# 2920737  19290190.0        29.0  Not Ejected   Does Not Apply  Does Not Apply
# 2920725  19290191.0        14.0  Not Ejected          Unknown   Hip-Upper Leg
# 2920723         NaN        26.0          NaN          Unknown   Hip-Upper Leg
# 2920722         NaN        48.0          NaN   Apparent Death         Unknown
# 2920721         NaN        31.0          NaN   Apparent Death         Unknown
# 2920720         NaN        47.0          NaN   Apparent Death         Unknown
#
#                                        POSITION_IN_VEHICLE  SAFETY_EQUIPMENT  \
# 2920724                                             Driver           Unknown
# 2920726                                                NaN               NaN
# 2920735  Any person in the rear of a station wagon, pic...           Unknown
# 2920736                                             Driver           Unknown
# 2920737                                             Driver  Air Bag Deployed
# 2920725  Any person in the rear of a station wagon, pic...           Unknown
# 2920723                                                NaN               NaN
# 2920722                                                NaN               NaN
# 2920721                                                NaN               NaN
# 2920720                                                NaN               NaN
#
#            PED_LOCATION      PED_ACTION       COMPLAINT    PED_ROLE  \
# 2920724             NaN             NaN         Unknown      Driver
# 2920726             NaN             NaN             NaN  Registrant
# 2920735             NaN             NaN         Unknown   Passenger
# 2920736             NaN             NaN         Unknown      Driver
# 2920737             NaN             NaN  Does Not Apply      Driver
# 2920725             NaN             NaN        Internal   Passenger
# 2920723  Does Not Apply  Not in Roadway    None Visible  Pedestrian
# 2920722  Does Not Apply  Not in Roadway         Unknown  Pedestrian
# 2920721  Does Not Apply  Not in Roadway         Unknown  Pedestrian
# 2920720  Does Not Apply  Not in Roadway         Unknown  Pedestrian
#
#         CONTRIBUTING_FACTOR_1 CONTRIBUTING_FACTOR_2 PERSON_SEX
# 2920724                   NaN                   NaN          M
# 2920726                   NaN                   NaN          U
# 2920735                   NaN                   NaN          M
# 2920736                   NaN                   NaN          M
# 2920737                   NaN                   NaN          M
# 2920725                   NaN                   NaN          F
# 2920723           Unspecified           Unspecified          F
# 2920722           Unspecified           Unspecified          M
# 2920721           Unspecified           Unspecified          F
# 2920720           Unspecified           Unspecified          M

# %% [markdown]
# Using group by(), we can aggregate the collision IDs and treat them each as one event,
# adding a count field to dataset to include the total number of people per collision.
# TRANSFORM function used to retain the number of rows in our original data-set

# %%
df1['count_col'] = df1.groupby(['COLLISION_ID'])[['COLLISION_ID']].transform('count')
df1 = df1.drop_duplicates('COLLISION_ID') # dropping repeat values in COLLISION_ID
df1.head(6)
# [[]] is needed to refer to the data frame column, if it was ['COLLISION_ID'], then it would return a pandas series.
# Out:
#     CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0   03/03/2020       0:00  BROOKLYN    11208  40.689920 -73.872610
# 12  03/03/2020      13:08  BROOKLYN    11219  40.636930 -73.986570
# 29  04/02/2015       8:30       NaN      NaN  40.772880 -73.831198
# 39  03/03/2020      17:33    QUEENS    11432  40.708770 -73.790504
# 40  10/17/2013      18:30       NaN      NaN  40.640037 -73.877941
# 57  09/02/2017      13:25  BROOKLYN    11203  40.650517 -73.923590
#
#                           LOCATION                    ON STREET NAME  \
# 0       POINT (-73.87261 40.68992)  HEMLOCK STREET
# 12      POINT (-73.98657 40.63693)                               NaN
# 29  POINT (-73.8311985 40.7728803)                               NaN
# 39     POINT (-73.790504 40.70877)                               NaN
# 40  POINT (-73.8779406 40.6400371)                               NaN
# 57     POINT (-73.92359 40.650517)  KINGS HIGHWAY
#
#    CROSS STREET NAME                           OFF STREET NAME  \
# 0     JAMAICA AVENUE                                       NaN
# 12               NaN  4312      14 AVENUE
# 29               NaN                                       NaN
# 39               NaN  170-12    90 AVENUE
# 40               NaN                                       NaN
# 57     SNYDER AVENUE                                       NaN
#
#     NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                         1.0                       0.0
# 12                        0.0                       0.0
# 29                        0.0                       0.0
# 39                        0.0                       0.0
# 40                        0.0                       0.0
# 57                        1.0                       0.0
#
#     NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 0                               1                             0
# 12                              0                             0
# 29                              0                             0
# 39                              0                             0
# 40                              0                             0
# 57                              0                             0
#
#     NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 0                           0                         0
# 12                          0                         0
# 29                          0                         0
# 39                          0                         0
# 40                          0                         0
# 57                          0                         0
#
#     NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 0                            0                          0
# 12                           0                          0
# 29                           0                          0
# 39                           0                          0
# 40                           0                          0
# 57                           1                          0
#
#    CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2  \
# 0                            NaN                           NaN
# 12                   Unspecified                   Unspecified
# 29       Outside Car Distraction                   Unspecified
# 39                   Unspecified                           NaN
# 40                   Unspecified                   Unspecified
# 57                   Unspecified                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                           NaN
# 12                           NaN                           NaN
# 29                           NaN                           NaN
# 39                           NaN                           NaN
# 40                           NaN                           NaN
# 57                           NaN                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4297861
# 12                           NaN       4297227
# 29                           NaN       3196670
# 39                           NaN       4297447
# 40                           NaN       2960273
# 57                           NaN       3745217
#
#                     VEHICLE TYPE CODE 1 VEHICLE TYPE CODE 2  \
# 0                                   NaN                 NaN
# 12                                Sedan               Sedan
# 29                    PASSENGER VEHICLE   PASSENGER VEHICLE
# 39  Station Wagon/Sport Utility Vehicle                 NaN
# 40                    PASSENGER VEHICLE   PASSENGER VEHICLE
# 57                    PASSENGER VEHICLE                 NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5   UNIQUE_ID  \
# 0                  NaN                 NaN                 NaN  10583927.0
# 12                 NaN                 NaN                 NaN  10580837.0
# 29                 NaN                 NaN                 NaN         NaN
# 39                 NaN                 NaN                 NaN  10581123.0
# 40                 NaN                 NaN                 NaN         NaN
# 57                 NaN                 NaN                 NaN   7248232.0
#
#     CRASH_DATE CRASH_TIME                             PERSON_ID PERSON_TYPE  \
# 0   03/03/2020       0:00  b266d854-0b05-44b5-ad74-940ceaa29ba4  Pedestrian
# 12  03/03/2020      13:08  d7faf68e-af75-4b3c-8b74-e45100ab3fc7    Occupant
# 29         NaN        NaN                                   NaN         NaN
# 39  03/03/2020      17:33  4471006f-6c83-4f6a-96c3-bc7659090e33    Occupant
# 40         NaN        NaN                                   NaN         NaN
# 57  09/02/2017      13:25  385e7c4d-261d-4070-8f4f-9c4448996e39    Occupant
#
#    PERSON_INJURY  VEHICLE_ID  PERSON_AGE     EJECTION EMOTIONAL_STATUS  \
# 0        Injured         NaN        21.0          NaN        Conscious
# 12   Unspecified  19310666.0        56.0  Not Ejected   Does Not Apply
# 29           NaN         NaN         NaN          NaN              NaN
# 39   Unspecified  19310817.0        53.0          NaN              NaN
# 40           NaN         NaN         NaN          NaN              NaN
# 57       Injured  17660318.0        41.0  Not Ejected        Conscious
#
#           BODILY_INJURY POSITION_IN_VEHICLE    SAFETY_EQUIPMENT  \
# 0   Knee-Lower Leg Foot                 NaN                 NaN
# 12       Does Not Apply              Driver  Lap Belt & Harness
# 29                  NaN                 NaN                 NaN
# 39                  NaN                 NaN                 NaN
# 40                  NaN                 NaN                 NaN
# 57                 Back              Driver  Lap Belt & Harness
#
#                                          PED_LOCATION            PED_ACTION  \
# 0   Pedestrian/Bicyclist/Other Pedestrian at Inter...  Crossing With Signal
# 12                                                NaN                   NaN
# 29                                                NaN                   NaN
# 39                                                NaN                   NaN
# 40                                                NaN                   NaN
# 57                                                NaN                   NaN
#
#                       COMPLAINT    PED_ROLE CONTRIBUTING_FACTOR_1  \
# 0   Complaint of Pain or Nausea  Pedestrian           Unspecified
# 12               Does Not Apply      Driver                   NaN
# 29                          NaN         NaN                   NaN
# 39                          NaN  Registrant                   NaN
# 40                          NaN         NaN                   NaN
# 57            Complaint of Pain      Driver                   NaN
#
#    CONTRIBUTING_FACTOR_2 PERSON_SEX  count_col
# 0            Unspecified          F          1
# 12                   NaN          M          4
# 29                   NaN        NaN          1
# 39                   NaN          M          1
# 40                   NaN        NaN          1
# 57                   NaN          M          3

# %% [markdown]
# The data has been cleaned well, will now be saved as a database file so additional filtering and spatial operations can be done in SQL through PostGIS environment.

# %%
# converting zip code to numeric to avoid errors once in PostGIS
df1["ZIP CODE"] = pd.to_numeric(df1["ZIP CODE"], errors = 'coerce')

# %%
# after trying to import into PostGIS, these columns were spit back as having mixed types.

# These columns are not necessary for calculations, can be removed.
cols = [3,32,37,38,39,40,41,43,44,45,46,47,48] #specifying columns based on list comprehension
df2 = df1.drop(df1.columns[cols], axis = 1) #dropping the columns

# %%
# make our dataframe into a GeoDataframe
df2['LOCATION'] = df2['LOCATION'].apply(wkt.loads) # refer to our LOCATION field as our geometry

gdf = gpd.GeoDataFrame(df2, geometry='LOCATION')
print("The number of records is currently: ",len(gdf))
gdf.head(2)
# Out:
# The number of records is currently:  1458849
#     CRASH DATE CRASH TIME   BOROUGH  LATITUDE  LONGITUDE  \
# 0   03/03/2020       0:00  BROOKLYN  40.68992  -73.87261
# 12  03/03/2020      13:08  BROOKLYN  40.63693  -73.98657
#
#                                LOCATION                    ON STREET NAME  \
# 0   POINT (-73.87260999999999 40.68992)  HEMLOCK STREET
# 12           POINT (-73.98657 40.63693)                               NaN
#
#    CROSS STREET NAME                           OFF STREET NAME  \
# 0     JAMAICA AVENUE                                       NaN
# 12               NaN  4312      14 AVENUE
#
#     NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                         1.0                       0.0
# 12                        0.0                       0.0
#
#     NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 0                               1                             0
# 12                              0                             0
#
#     NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 0                           0                         0
# 12                          0                         0
#
#     NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 0                            0                          0
# 12                           0                          0
#
#    CONTRIBUTING FACTOR VEHICLE 1 CONTRIBUTING FACTOR VEHICLE 2  \
# 0                            NaN                           NaN
# 12                   Unspecified                   Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                           NaN
# 12                           NaN                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID VEHICLE TYPE CODE 1  \
# 0                            NaN       4297861                 NaN
# 12                           NaN       4297227               Sedan
#
#    VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                  NaN                 NaN                 NaN
# 12               Sedan                 NaN                 NaN
#
#    VEHICLE TYPE CODE 5   UNIQUE_ID  CRASH_DATE CRASH_TIME PERSON_TYPE  \
# 0                  NaN  10583927.0  03/03/2020       0:00  Pedestrian
# 12                 NaN  10580837.0  03/03/2020      13:08    Occupant
#
#    PERSON_INJURY  VEHICLE_ID  PERSON_AGE  \
# 0        Injured         NaN        21.0
# 12   Unspecified  19310666.0        56.0
#
#                                          PED_LOCATION  count_col
# 0   Pedestrian/Bicyclist/Other Pedestrian at Inter...          1
# 12                                                NaN          4

# %% [markdown]
# PostGIS can be a bit 'finnicky' when importing dataframes. To improve our data,
# we will lowercase all columns and remove whitespace, replacing them with '_'

# %%
# lowercasing with for loop
gdf.columns = [x.lower() for x in gdf.columns]
# replacing spaces with _
gdf.columns = gdf.columns.str.replace(' ', '_')
gdf.head(5)
# Out:
#     crash_date crash_time   borough   latitude  longitude  \
# 0   03/03/2020       0:00  BROOKLYN  40.689920 -73.872610
# 12  03/03/2020      13:08  BROOKLYN  40.636930 -73.986570
# 29  04/02/2015       8:30       NaN  40.772880 -73.831198
# 39  03/03/2020      17:33    QUEENS  40.708770 -73.790504
# 40  10/17/2013      18:30       NaN  40.640037 -73.877941
#
#                                location                    on_street_name  \
# 0   POINT (-73.87260999999999 40.68992)  HEMLOCK STREET
# 12           POINT (-73.98657 40.63693)                               NaN
# 29       POINT (-73.8311985 40.7728803)                               NaN
# 39          POINT (-73.790504 40.70877)                               NaN
# 40       POINT (-73.8779406 40.6400371)                               NaN
#
#    cross_street_name                           off_street_name  \
# 0     JAMAICA AVENUE                                       NaN
# 12               NaN  4312      14 AVENUE
# 29               NaN                                       NaN
# 39               NaN  170-12    90 AVENUE
# 40               NaN                                       NaN
#
#     number_of_persons_injured  number_of_persons_killed  \
# 0                         1.0                       0.0
# 12                        0.0                       0.0
# 29                        0.0                       0.0
# 39                        0.0                       0.0
# 40                        0.0                       0.0
#
#     number_of_pedestrians_injured  number_of_pedestrians_killed  \
# 0                               1                             0
# 12                              0                             0
# 29                              0                             0
# 39                              0                             0
# 40                              0                             0
#
#     number_of_cyclist_injured  number_of_cyclist_killed  \
# 0                           0                         0
# 12                          0                         0
# 29                          0                         0
# 39                          0                         0
# 40                          0                         0
#
#     number_of_motorist_injured  number_of_motorist_killed  \
# 0                            0                          0
# 12                           0                          0
# 29                           0                          0
# 39                           0                          0
# 40                           0                          0
#
#    contributing_factor_vehicle_1 contributing_factor_vehicle_2  \
# 0                            NaN                           NaN
# 12                   Unspecified                   Unspecified
# 29       Outside Car Distraction                   Unspecified
# 39                   Unspecified                           NaN
# 40                   Unspecified                   Unspecified
#
#    contributing_factor_vehicle_3 contributing_factor_vehicle_4  \
# 0                            NaN                           NaN
# 12                           NaN                           NaN
# 29                           NaN                           NaN
# 39                           NaN                           NaN
# 40                           NaN                           NaN
#
#    contributing_factor_vehicle_5  collision_id  \
# 0                            NaN       4297861
# 12                           NaN       4297227
# 29                           NaN       3196670
# 39                           NaN       4297447
# 40                           NaN       2960273
#
#                     vehicle_type_code_1 vehicle_type_code_2  \
# 0                                   NaN                 NaN
# 12                                Sedan               Sedan
# 29                    PASSENGER VEHICLE   PASSENGER VEHICLE
# 39  Station Wagon/Sport Utility Vehicle                 NaN
# 40                    PASSENGER VEHICLE   PASSENGER VEHICLE
#
#    vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5   unique_id  \
# 0                  NaN                 NaN                 NaN  10583927.0
# 12                 NaN                 NaN                 NaN  10580837.0
# 29                 NaN                 NaN                 NaN         NaN
# 39                 NaN                 NaN                 NaN  10581123.0
# 40                 NaN                 NaN                 NaN         NaN
#
#     crash_date crash_time person_type person_injury  vehicle_id  person_age  \
# 0   03/03/2020       0:00  Pedestrian       Injured         NaN        21.0
# 12  03/03/2020      13:08    Occupant   Unspecified  19310666.0        56.0
# 29         NaN        NaN         NaN           NaN         NaN         NaN
# 39  03/03/2020      17:33    Occupant   Unspecified  19310817.0        53.0
# 40         NaN        NaN         NaN           NaN         NaN         NaN
#
#                                          ped_location  count_col
# 0   Pedestrian/Bicyclist/Other Pedestrian at Inter...          1
# 12                                                NaN          4
# 29                                                NaN          1
# 39                                                NaN          1
# 40                                                NaN          1

# %%
#save as CSV file
gdf.to_csv(r'filepath\table.csv', index = False)

# %%
# importing this data directly into postGIS
hostNameStr = 'localhost'; portNumber  = '5432'
userNameStr = 'postgres' ; passwordStr = 'pw'
databaseStr = 'postgres' ; tableName = 'collision_data'

csvFileName = r'filepath.csv'
# refine path when sharing
#connection format
'dialect+driver://username:password@host:port/database'
dbEngine = create_engine('postgresql://' \
    + userNameStr + ':' + passwordStr \
        + '@' + hostNameStr + ':' + portNumber \
            + '/' + databaseStr)
gdf = pd.read_csv(csvFileName)
gdf.to_sql(tableName, dbEngine)
# Out:
# C:\Users\steve\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# check the length of the data
print("The number of records is currently: ",len(gdf))
# Out:
# The number of records is currently:  1458849

# %% [markdown]
# There are currently 1,458,849 unique collision records in the data table. From here, we need to aggregate this data based off each individual NYC intersection with collision data.
# View part 2 of the project: Spatial Operations in PostGIS
